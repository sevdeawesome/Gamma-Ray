# %%
## IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("track3/NA23.csv")

# %%
data
# Out:
#       Channel     Energy  Counts
# 0           1    -3.9162       0
# 1           2    -3.6975       1
# 2           3    -3.4788       0
# 3           4    -3.2600       4
# 4           5    -3.0413      39
# ...       ...        ...     ...
# 8187     8188  1786.7102       0
# 8188     8189  1786.9289       0
# 8189     8190  1787.1476       0
# 8190     8191  1787.3663       0
# 8191     8192  1787.5851       0
#
# [8192 rows x 3 columns]

# %%
data["Channel"]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 8187    8188
# 8188    8189
# 8189    8190
# 8190    8191
# 8191    8192
# Name: Channel, Length: 8192, dtype: int64

# %%
plt.plot(data["Energy"],data["Counts"] )
plt.title('Na 23 Isotope')
plt.xlabel('Energy')
plt.ylabel('Counts')
plt.savefig("figs/na23full")

# %% [markdown]
# ## first peak (only peak)

# %%
variancedata = data.iloc[2000:2700,:]
# variancedata
plt.plot(variancedata["Energy"], variancedata["Counts"])
plt.title('Na 23 Isotope Peak')
plt.xlabel('Energy')
plt.ylabel('Counts')

plt.savefig("figs/na23peak")

# %% [markdown]
# ## std deviation:

# %%
variancedata.std()
# Out:
# Channel     202.216880
# Energy       44.228030
# Counts     2029.751448
# dtype: float64

# %%
variancedata = data.iloc[5000:7000,:]
# variancedata
plt.plot(variancedata["Energy"], variancedata["Counts"])
plt.title('Na 23 Isotope Peak')
plt.xlabel('Energy')
plt.ylabel('Counts')
plt.savefig("figs/na23peak2")

# %%
variancedata.std()
# Out:
# Channel    577.494589
# Energy     126.307201
# Counts     337.931621
# dtype: float64
