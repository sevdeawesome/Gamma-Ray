# %%
## IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("track3/CO57.csv")

# %%
data
# Out:
#       Channel     Energy  Counts
# 0           1    -3.9162       0
# 1           2    -3.6975       1
# 2           3    -3.4788       0
# 3           4    -3.2600       0
# 4           5    -3.0413       2
# ...       ...        ...     ...
# 8187     8188  1786.7102       0
# 8188     8189  1786.9289       0
# 8189     8190  1787.1476       0
# 8190     8191  1787.3663       0
# 8191     8192  1787.5851       0
#
# [8192 rows x 3 columns]

# %%
data["Channel"]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 8187    8188
# 8188    8189
# 8189    8190
# 8190    8191
# 8191    8192
# Name: Channel, Length: 8192, dtype: int64

# %%
plt.plot(data["Energy"],data["Counts"] )

# %%
variancedata = data.iloc[480:600,:]
plt.plot(variancedata["Energy"],variancedata["Counts"])
plt.title('Co 57 Isotope Compton Edge')
plt.xlabel('Energy')
plt.ylabel('Counts')


ax = plt.gca()
# ax.set_xlim([0,100])
# ax.set_ylim([0, 100])
# plt.savefig("co57compton.png")

# %%
variancedata.std()
# Out:
# Channel    34.785054
# Energy      7.608043
# Counts     19.941495
# dtype: float64
